# %%
'''

Konkani integer tracription system

This code  takes Konkani integer either in devnagari or roman and provides 
Transcription in Devnagari text and phonetic trascription.

For eg 1150 [ek h@>dzar ekshE p@nnas] एक हजार एकशे पन्नास
'''
# Out:
# '\n\nKonkani integer tracription system\n\nThis code  takes Konkani integer either in devnagari or roman and provides \nTranscription in Devnagari text and phonetic trascription.\n\nFor eg 1150 [ek h@>dzar ekshE p@nnas] एक हजार एकशे पन्नास\n'

# %%
#converting devnagari integer to roman
#all={
#    "0":"०", "1":"१", "2":"२", "3":"३", "4":"४", "5":"५", "6":"६", "7":"७", "8":"८", "9":"९", "०":0, "१":1, "२":2, "३":3, "४":4, "५":5, "६":6, "७":7, "८":8, "९":9		
#}

value="१२३"

def dev_int_to_roman(value):
    all={ "१":1, "२":2, "३":3, "४":4, "५":5, "६":6, "७":7, "८":8, "९":9
        }
    store = " "
    result = ""
    for i in value:
        if i in all:
            store = all.get(i)
            result += str(store)
    return result

new=str(input("Enter a number "))
dev_int_to_roman(new)
# Out:
# Enter a number 232
# ''

# %%
#code for integer trascription
Num={
0:"शुन्य", 
1:"एक",
2:"दोन",
3:"तीन",
4:"चार",
5:"पांच",
6:"स",
7:"सात",
8:"आठ",
9:"णव",
10:"धा",
11:"इकरा",
12:"बारा",
13:"तेरा",
14:"चवदा",
15:"पंदरा",
16:"सोळा",
17:"सतरा",
18:"अठरा",
19:"एकुणीस",
20:"वीस",
21:"एकवीस",
22:"बावीस",
23:"तेवीस",
24:"चोवीस",
25:"पंचवीस",
26:"सव्वीस",
27:"सत्तावीस",
28:"अठ्ठावीस",
29:"एकुणतीस",
30:"तीस",
31:"एकतीस",
32:"बत्तीस",
33:"तेत्तीस",
34:"चवतीस",
35:"पस्तीस",
36:"छत्तीस",
37:"सात्तीस",
38:"आठ्ठीस",
39:"एकुणचाळीस",
40:"चाळीस",
41:"एकेचाळीस",
42:"बेचाळीस",
43:"त्रेचाळीस",
44:"चवेचाळीस",
45:"पंचेचाळीस",
46:"शेचाळीस",
47:"सत्तेचाळीस",
48:"अठ्ठेचाळीस",
49:"एकुणपन्नास",
50:"पन्नास",
51:"एकावन",
52:"बावन",
53:"त्रेप्पन",
54:"चौपन",
55:"पंचावन",
56:"छाप्पन",
57:"सत्तावन",
58:"अठ्ठावन",
59:"एकुणसाठ",
60:"साठ",
61:"एकसठ",
62:"बांसठ",
63:"त्रेंसठ",
64:"चवसठ",
65:"पांसठ",
66:"सांसठ",
67:"सातसठ",
68:"आठसठ",
69:"एकुणसत्तर",
70:"सत्तर",
71:"एक्यात्तर",
72:"ब्यात्तर",
73:"त्र्यात्तर",
74:"चवद्यात्तर",
75:"पंच्यात्तर",
76:"शात्तर",
77:"सत्त्यात्तर",
78:"अठ्ठ्यात्तर",
79:"एकुणअंयशीं",
80:"अंयशीं",
81:"एक्यांयशीं",
82:"ब्यांयशीं",
83:"त्र्यांयशीं",
84:"चवद्यांयशीं",
85:"पंच्यांयशीं",
86:"श्यांयशीं",
87:"सत्त्यांयशीं",
88:"अठ्ठ्यांयशीं",
89:"एकुणणव्वद",
90:"णव्वद",
91:"एक्याण्णव",
92:"ब्याण्णव",
93:"त्र्याण्णव",
94:"चवद्याण्णव",
95:"पंच्याण्णव",
96:"शाण्णव",
97:"सत्त्याण्णव",
98:"अठ्ठ्याण्णव",
99:"णव्याण्णव",
100:"शंबर",
}



#dictionary used by position_mapping method
pos_map_dict={3:"शे", 4:"हजार",6:"लाख",8:"कोटी",10:"अरब",12:"खरब"}

def konk_int_transcrition(integer):
    y=""
    z=""
    X=integer
    N=len(str(X))
    
    if N>=12:
        RIGHT=integer%100000000000
        LEFT=integer//100000000000
        
        #print("right:",RIGHT)
        #print("left:",LEFT)
        y=left_transcription(LEFT)+" "+position_mapping(12)+" "+right_transcription(RIGHT)
    else:
        y=right_transcription(X)
    print (y)
    return y

def right_transcription(right):
    y=""
    X=right
    N=len(str(X))
    
    if N<=2:
        if N==0:
            return y
        else:
            y=integer_mapping(X)
    elif N<=3:
        #special exception to print 100
        if(X==100):
            y=integer_mapping(X)
        else:
            LEFT=X//100
            RIGHT=X%100
            #print("right:",RIGHT)
            #print("left:",LEFT)
            #no sapce is used as to combine she (hundread position) with integer
            y=integer_mapping(LEFT)+position_mapping(3)+" "+right_transcription(RIGHT)
    elif N<=5:
        LEFT=X//1000
        RIGHT=X%1000
        #print("right:",RIGHT)
        #print("left:",LEFT)
        y=integer_mapping(LEFT)+" "+position_mapping(4)+" "+right_transcription(RIGHT)
    elif N<=7:
        LEFT=X//100000
        RIGHT=X%100000
        #print("right:",RIGHT)
        #print("left:",LEFT)
        y=integer_mapping(LEFT)+" "+position_mapping(6)+" "+right_transcription(RIGHT)
    elif N<=9:
        LEFT=X//10000000
        RIGHT=X%10000000
        #print("right:",RIGHT)
        #print("left:",LEFT)
        y=integer_mapping(LEFT)+" "+position_mapping(8)+" "+right_transcription(RIGHT)
    #elif N<=11:
    else:
        LEFT=X//1000000000
        RIGHT=X%1000000000
        #print("right:",RIGHT)
        #print("left:",LEFT)
        y=integer_mapping(LEFT)+" "+position_mapping(10)+" "+right_transcription(RIGHT)
    '''
    else:
        LEFT=X//100000000000
        RIGHT=X%100000000000
        #print("right:",RIGHT)
        #print("left:",LEFT)
        y=left_transcription(LEFT)+" "+position_mapping(12)+" "+right_transcription(RIGHT)
    '''
    return y

def left_transcription(left):
    y=""
    X=left
    N=len(str(X))
    
    if N>=9:
        RIGHT=X%1000000000
        LEFT=X//1000000000
        
        #print("right:",RIGHT)
        #print("left:",LEFT)
        y=left_transcription(LEFT)+" "+position_mapping(10)+" "+right_transcription(RIGHT)
    else:
        y=right_transcription(X)
    return y
    
def position_mapping(n):
    if n>=12:
        return pos_map_dict.get(12)
    elif n>=10:
        return pos_map_dict.get(10)
    elif n>=8:
        return pos_map_dict.get(8)
    elif n>=6:
        return pos_map_dict.get(6)
    elif n>=4:
        return pos_map_dict.get(4)
    else:
        return pos_map_dict.get(3)

def integer_mapping(integer):
    y=""
    num=int(integer)
    if num>0:
        y+= Num.get(num)
    #print (y)
    return y
    
konk_int_transcrition(123456789223344556677888888966)
#konk_phonetic_int_transcrition(123456789223344556677888888966)
#konk_int_transcrition(100000000000000000000000000000000000000)
#konk_int_transcrition(10000000000100000000)
# Out:
# एक अरब तेवीस कोटी पंचेचाळीस लाख सातसठ हजार आठशे ब्याण्णव अरब तेवीस कोटी चवतीस लाख पंचेचाळीस हजार पांचशे सांसठ खरब सत्त्यात्तर अरब अठ्ठ्यांयशीं कोटी अठ्ठ्यांयशीं लाख अठ्ठ्यांयशीं हजार णवशे सांसठ
# 'एक अरब तेवीस कोटी पंचेचाळीस लाख सातसठ हजार आठशे ब्याण्णव अरब तेवीस कोटी चवतीस लाख पंचेचाळीस हजार पांचशे सांसठ खरब सत्त्यात्तर अरब अठ्ठ्यांयशीं कोटी अठ्ठ्यांयशीं लाख अठ्ठ्यांयशीं हजार णवशे सांसठ'

# %%
#Phonetic trancription code 
phonetic_num={
0:"ʃuɲjᵊ",
1:"e:k",
2:"do:n",
3:"ti:n",
4:"t͡ʃa:r",
5:"pã:t͡s",
6:"sɨ:",
7:"sa:t",
8:"a:ʈ",
9:"ɳə̃ʋ",
10:"dʱa:",
11:"ikra",
12:"barav",
13:"tɛra",
14:"t͡sɨʋda",
15:"pənra",
16:"sɔɭav",
17:"sɨtra",
18:"ɨʈra",
19:"ekuɳis",
20:"vi:s",
21:"ekvis",
22:"bavis",
23:"tevis",
24:"t͡ʃovis",
25:"pə̃ɲt͡ʃvis",
26:"sɨvvis",
27:"səttavis",
28:"əʈʈavis",
29:"ekuɳʈis",
30:"ti:s",
31:"ektis",
32:"bəttis",
33:"tɛttis",
34:"t͡sɨʋtis",
35:"pəstis",
36:"t͡ʃʰəttis",
37:"sattis",
38:"aʈʈis",
39:"ekuɳt͡ʃaɭis",
40:"t͡ʃaɭis",
41:"eket͡ʃaɭis",
42:"bet͡ʃaɭis",
43:"tret͡ʃaɭis",
44:"t͡səvet͡ʃaɭis",
45:"pəɲt͡ʃet͡ʃaɭis",
46:"ʃet͡ʃaɭis",
47:"səttet͡ʃaɭis",
48:"əʈʈet͡ʃaɭis",
49:"ekuɳpənnas",
50:"pənnas",
51:"ɛkavən",
52:"bavən",
53:"treppən",
54:"t͡ʃoʋpən",
55:"pə̃nt͡savən",
56:"t͡ʃʰappən",
57:"səttavən",
58:"əʈʈavən",
59:"ekuɳsaʈ",
60:"sa:ʈ",
61:"eksəʈ",
62:"bãsəʈ",
63:"trẽsəʈ",
64:"t͡sɨʋsəʈ",
65:"pãsəʈ",
66:"sãsəʈ",
67:"satsəʈ",
68:"aʈsəʈ",
69:"ekuɳsɨttɨr",
70:"sɨttɨr",
71:"ɛkjattər",
72:"bjattər",
73:"trjattər",
74:"t͡səʋdjattər",
75:"pəɲt͡ʃattər",
76:"ʃattər",
77:"səttjattər",
78:"əʈʈʰjattər",
79:"ekuɳə̃jʃĩ",
80:"ə̃jʃĩ",
81:"ɛkjãjʃĩ",
82:"bjãjʃĩ",
83:"trãjʃĩ",
84:"t͡səʋdjãjʃĩ",
85:"pə̃ɲt͡ʃãjʃĩ",
86:"ʃãjʃĩ",
87:"səttjãjʃĩ",
88:"əʈʈʰjãjʃĩ",
89:"ekuɳɳəʋʋəd",
90:"ɳəʋʋəd",
91:"ɛkjaɳɳə̃ʋ",
92:"bjaɳɳə̃ʋ",
93:"trjaɳɳə̃ʋ",
94:"t͡səʋdjaɳɳə̃ʋ",
95:"pə̃ɲt͡ʃaɳɳə̃ʋ",
96:"ʃaɳɳə̃ʋ",
97:"səttjaɳɳə̃ʋ",
98:"əʈʈʰjaɳɳə̃ʋ",
99:"ɳəʋjaɳɳə̃ʋ",
100:"ʃɨmbɨr"
}

phonetic_pos_map_dict={3:"ʃɛ", 4:"həd͡zar",6:"lakʰ",8:"koʈi",10:"ərəb",12:"kʰərəb "}

def phonetic_integer_mapping(integer):
    y=""
    num=int(integer)
    if num>0:
        y+= phonetic_num.get(num)
    return y

# phonetic konkani transcription
def konk_phonetic_int_transcrition(integer):
    y=""
    z=""
    X=integer
    N=len(str(X))
    
    if N>=12:
        RIGHT=integer%100000000000
        LEFT=integer//100000000000
        
        #print("right:",RIGHT)
        #print("left:",LEFT)
        y=phonetic_left_transcription(LEFT)+" "+phonetic_position_mapping(12)+" "+phonetic_right_transcription(RIGHT)
    else:
        y=phonetic_right_transcription(X)
    print (y)
    return y

def phonetic_right_transcription(right):
    y=""
    X=right
    N=len(str(X))
    
    if N<=2:
        if N==0:
            return y
        else:
            y=phonetic_integer_mapping(X)
    elif N<=3:
        #special exception to print 100
        if(X==100):
            y=phonetic_integer_mapping(X)
        else:
            LEFT=X//100
            RIGHT=X%100
            #print("right:",RIGHT)
            #print("left:",LEFT)
            #no sapce is used as to combine she (hundread position) with integer
            y=phonetic_integer_mapping(LEFT)+phonetic_position_mapping(3)+" "+phonetic_right_transcription(RIGHT)
    elif N<=5:
        LEFT=X//1000
        RIGHT=X%1000
        #print("right:",RIGHT)
        #print("left:",LEFT)
        y=phonetic_integer_mapping(LEFT)+" "+phonetic_position_mapping(4)+" "+phonetic_right_transcription(RIGHT)
    elif N<=7:
        LEFT=X//100000
        RIGHT=X%100000
        #print("right:",RIGHT)
        #print("left:",LEFT)
        y=phonetic_integer_mapping(LEFT)+" "+phonetic_position_mapping(6)+" "+phonetic_right_transcription(RIGHT)
    elif N<=9:
        LEFT=X//10000000
        RIGHT=X%10000000
        #print("right:",RIGHT)
        #print("left:",LEFT)
        y=phonetic_integer_mapping(LEFT)+" "+phonetic_position_mapping(8)+" "+phonetic_right_transcription(RIGHT)
    #elif N<=11:
    else:
        LEFT=X//1000000000
        RIGHT=X%1000000000
        #print("right:",RIGHT)
        #print("left:",LEFT)
        y=phonetic_integer_mapping(LEFT)+" "+phonetic_position_mapping(10)+" "+phonetic_right_transcription(RIGHT)
    '''
    else:
        LEFT=X//100000000000
        RIGHT=X%100000000000
        #print("right:",RIGHT)
        #print("left:",LEFT)
        y=phonetic_left_transcription(LEFT)+" "+phonetic_position_mapping(12)+" "+phonetic_right_transcription(RIGHT)
    '''
    return y

def phonetic_left_transcription(left):
    y=""
    X=left
    N=len(str(X))
    
    if N>=9:
        RIGHT=X%1000000000
        LEFT=X//1000000000
        
        #print("right:",RIGHT)
        #print("left:",LEFT)
        y=phonetic_left_transcription(LEFT)+" "+phonetic_position_mapping(10)+" "+phonetic_right_transcription(RIGHT)
    else:
        y=phonetic_right_transcription(X)
    return y
    
def phonetic_position_mapping(n):
    if n>=12:
        return phonetic_pos_map_dict.get(12)
    elif n>=10:
        return phonetic_pos_map_dict.get(10)
    elif n>=8:
        return phonetic_pos_map_dict.get(8)
    elif n>=6:
        return phonetic_pos_map_dict.get(6)
    elif n>=4:
        return phonetic_pos_map_dict.get(4)
    else:
        return phonetic_pos_map_dict.get(3)

def integer_mapping(integer):
    y=""
    num=int(integer)
    if num>0:
        y+= phonetic_num.get(num)
    #print (y)
    return y

#konk_int_transcrition(123456789223344556677888888966)
konk_phonetic_int_transcrition(123456789223344556677888888966)
#konk_int_transcrition(100000000000000000000000000000000000000)
#konk_int_transcrition(10000000000100000000)
# Out:
# e:k ərəb tevis koʈi pəɲt͡ʃet͡ʃaɭis lakʰ satsəʈ həd͡zar a:ʈʃɛ bjaɳɳə̃ʋ ərəb tevis koʈi t͡sɨʋtis lakʰ pəɲt͡ʃet͡ʃaɭis həd͡zar pã:t͡sʃɛ sãsəʈ kʰərəb  səttjattər ərəb əʈʈʰjãjʃĩ koʈi əʈʈʰjãjʃĩ lakʰ əʈʈʰjãjʃĩ həd͡zar ɳə̃ʋʃɛ sãsəʈ
# 'e:k ərəb tevis koʈi pəɲt͡ʃet͡ʃaɭis lakʰ satsəʈ həd͡zar a:ʈʃɛ bjaɳɳə̃ʋ ərəb tevis koʈi t͡sɨʋtis lakʰ pəɲt͡ʃet͡ʃaɭis həd͡zar pã:t͡sʃɛ sãsəʈ kʰərəb  səttjattər ərəb əʈʈʰjãjʃĩ koʈi əʈʈʰjãjʃĩ lakʰ əʈʈʰjãjʃĩ həd͡zar ɳə̃ʋʃɛ sãsəʈ'
